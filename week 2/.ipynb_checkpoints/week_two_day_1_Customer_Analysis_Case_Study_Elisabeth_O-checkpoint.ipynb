# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statsmodels.api as sm
from scipy.stats import boxcox

pd.options.display.max_rows = 100
## Install xlrd package to load Excel files
#!conda install openpyxl
#!conda install xlrd

# %% [markdown]
# # Activity 1 (Monday)

# %% [markdown]
# ## insert data
# - Aggregate data into one Data Frame using Pandas.
# - Pay attention that files may have different names for the same column. therefore, make sure that you unify the columns names before concating them.

# %%
def original_data():
    file1 = pd.read_csv("data/file1.csv")
    file2 = pd.read_csv("data/file2.csv")
    file3 = pd.read_csv("data/file3.csv")
    return pd.concat([file1,file2,file3], axis=0) #axis =0 means concat rowwise

# %%
cu_df=original_data()

# %%
cu_df
# Out:
#      Customer       State Gender             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %% [markdown]
# ## Standardizing
# - Standardizing header names

# %% [markdown]
#  **Did the standardizing in the files before uploading them to the notebook**
#
#  but im going to lower them...

# %%
def lower_case_header(cu_df):
    cu_df.columns=[i.lower() for i in cu_df.columns]
    return cu_df

lower_case_header(cu_df)
# Out:
#            state gender             education customer lifetime value  \
# 0     Washington    NaN                Master                     NaN
# 1        Arizona      F              Bachelor              697953.59%
# 2         Nevada      F              Bachelor             1288743.17%
# 3     California      M              Bachelor              764586.18%
# 4     Washington      M  High School or Below              536307.65%
# ...          ...    ...                   ...                     ...
# 7065  California      M              Bachelor             23405.98798
# 7066  California      F               College             3096.511217
# 7067  California      M              Bachelor             8163.890428
# 7068  California      M               College             7524.442436
# 7069  California      M               College             2611.836866
#
#        income  monthly premium auto number of open complaints     policy type  \
# ...

# %% [markdown]
# ## Delete columns
# - Deleting and rearranging columns - delete the column customer as it is only a unique identifier for each row of data

# %%
cu_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12074 entries, 0 to 7069
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   9137 non-null   object
#  1   state                      9137 non-null   object
#  2   gender                     9015 non-null   object
#  3   education                  9137 non-null   object
#  4   customer lifetime value    9130 non-null   object
#  5   income                     9137 non-null   float64
#  6   monthly premium auto       9137 non-null   float64
#  7   number of open complaints  9137 non-null   object
#  8   policy type                9137 non-null   object
#  9   vehicle class              9137 non-null   object
#  10  total claim amount         9137 non-null   float64
# dtypes: float64(3), object(8)
# memory usage: 1.1+ MB

# %%
del cu_df["customer"]
cu_df
# Out:
#            state gender             education customer lifetime value  \
# 0     Washington    NaN                Master                     NaN
# 1        Arizona      F              Bachelor              697953.59%
# 2         Nevada      F              Bachelor             1288743.17%
# 3     California      M              Bachelor              764586.18%
# 4     Washington      M  High School or Below              536307.65%
# ...          ...    ...                   ...                     ...
# 7065  California      M              Bachelor             23405.98798
# 7066  California      F               College             3096.511217
# 7067  California      M              Bachelor             8163.890428
# 7068  California      M               College             7524.442436
# 7069  California      M               College             2611.836866
#
#        income  monthly premium auto number of open complaints     policy type  \
# ...

# %% [markdown]
# ## Working with data types
# - Check the data types of all the columns and fix the incorrect ones (for ex. customer lifetime value and number of open complaints ).
# - remove the percentage from the customer lifetime value and truncate it to an integer value.

# %%
cu_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12074 entries, 0 to 7069
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   state                      9137 non-null   object
#  1   gender                     9015 non-null   object
#  2   education                  9137 non-null   object
#  3   customer lifetime value    9130 non-null   object
#  4   income                     9137 non-null   float64
#  5   monthly premium auto       9137 non-null   float64
#  6   number of open complaints  9137 non-null   object
#  7   policy type                9137 non-null   object
#  8   vehicle class              9137 non-null   object
#  9   total claim amount         9137 non-null   float64
# dtypes: float64(3), object(7)
# memory usage: 1.0+ MB

# %%
cu_df.state.unique()
# Out:
# array(['Washington', 'Arizona', 'Nevada', 'California', 'Oregon', 'Cali',
#        'AZ', 'WA', nan], dtype=object)

# %%
cu_df[cu_df["state"]=="AZ"]= "Arizona"
cu_df[cu_df["state"]=="WA"]= "Washington"
cu_df[cu_df["state"]=="Cali"]= "California"
cu_df[cu_df["state"]=="nan"]= np.nan
cu_df.state.unique().tolist()
# Out:
# ['Washington', 'Arizona', 'Nevada', 'California', 'Oregon', nan]

# %%
cu_df["customer lifetime value"]=pd.to_numeric(cu_df["customer lifetime value"],errors="coerce")

# %%
cu_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12074 entries, 0 to 7069
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   state                      9137 non-null   object
#  1   gender                     9028 non-null   object
#  2   education                  9137 non-null   object
#  3   customer lifetime value    1836 non-null   float64
#  4   income                     9137 non-null   object
#  5   monthly premium auto       9137 non-null   object
#  6   number of open complaints  9137 non-null   object
#  7   policy type                9137 non-null   object
#  8   vehicle class              9137 non-null   object
#  9   total claim amount         9137 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 1.0+ MB

# %%
cu_df["total claim amount"]=pd.to_numeric(cu_df["total claim amount"],errors="coerce")

# %%
cu_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12074 entries, 0 to 7069
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   state                      9137 non-null   object
#  1   gender                     9028 non-null   object
#  2   education                  9137 non-null   object
#  3   customer lifetime value    1836 non-null   float64
#  4   income                     9137 non-null   object
#  5   monthly premium auto       9137 non-null   object
#  6   number of open complaints  9137 non-null   object
#  7   policy type                9137 non-null   object
#  8   vehicle class              9137 non-null   object
#  9   total claim amount         8913 non-null   float64
# dtypes: float64(2), object(8)
# memory usage: 1.0+ MB

# %%
cu_df["monthly premium auto"]=pd.to_numeric(cu_df["monthly premium auto"],errors="coerce")

# %%
cu_df["income"]=pd.to_numeric(cu_df["income"],errors="coerce")

# %%
cu_df
# Out:
#            state gender             education  customer lifetime value  \
# 0     Washington    NaN                Master                      NaN
# 1        Arizona      F              Bachelor                697953.59
# 2         Nevada      F              Bachelor               1288743.17
# 3     California      M              Bachelor                764586.18
# 4     Washington      M  High School or Below                536307.65
# ...          ...    ...                   ...                      ...
# 7065  California      M              Bachelor                      NaN
# 7066  California      F               College                      NaN
# 7067  California      M              Bachelor                      NaN
# 7068  California      M               College                      NaN
# 7069  California      M               College                      NaN
#
#        income  monthly premium auto number of open complaints     policy type  \
# ...

# %%
cu_df.gender.unique()
# Out:
# array([nan, 'F', 'M', 'California', 'Arizona', 'Washington', 'Femal',
#        'Male', 'female'], dtype=object)

# %%
cu_df["gender"].value_counts()
# Out:
# F             4460
# M             4269
# California     120
# Arizona         74
# Male            34
# Washington      30
# female          29
# Femal           12
# Name: gender, dtype: int64
