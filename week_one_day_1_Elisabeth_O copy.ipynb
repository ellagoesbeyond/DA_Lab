# %% [markdown]
# # The hipster hiker

# %% [markdown]
# Purpose: You gonna get an introduction to my fav hobby. **HIKING** 🥾

# %% [markdown]
# ## Me
# Hi - I'm Lizz

# %%
innit_def: 
    x=Lizz
# Out:
#   Input In [1]
#     innit_def:
#                ^
# SyntaxError: invalid syntax

# %%
def me(): 
    me=("Lizz")

# %%
from IPython.display import Image
Image ("Photos/me.JPG", width=200, height=200)

# %% [markdown]
# ## The Alps

# %% [markdown]
# Thats the destination Im heading to. Maybe you heared about the famous E5 path. Where in the neolithic time age [Hannibal] (https://www.smithsonianmag.com/history/how-hannibal-crossed-the-alps-180963671/) walked over the alps accompanied by 200 elefants. There of only a few survive.

# %% [markdown]
# <font color='green'>In 2019 I crossed the alps from Oberstdorf (GER) to Meran (IT)</font>

# %%
from IPython.display import Image 
Image ("https://mamawandert.files.wordpress.com/2019/11/12384315-5bb2-4d1e-9fbc-c275cdaa4381.jpeg")

# %%
from IPython.display import Image 
Image ("ttps://mamawandert.files.wordpress.com/2019/10/671be175-86d4-4da4-a1b1-1c2aa6507475.jpeg?w=1344
# Out:
#   Input In [23]
#     Image ("https://mamawandert.files.wordpress.com/2019/10/671be175-86d4-4da4-a1b1-1c2aa6507475.jpeg?w=1344
#                                                                                                             ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
# Hey thats me - my aunt writes a blog about hiking. visit [mama wandert](https://mama-wandert.com/2019/10/22/2019-kilometer-11-hiker-im-schlagermodus-oder-wie-ich-ueber-die-alpen-ging-teil-3/)

# %% [markdown]
# ### why i  enjoy hiking in the alps

# %% [markdown]
# - silence. your able to bond with the nature
# - im a city girl. I need to calm down sometimes
# - freedom

# %%
from IPython.display import HTML
HTML ("<iframe width="560" height="315" src="https://www.youtube.com/embed/lSM0VAqSOeg" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>")
# Out:
#   Input In [31]
#     HTML ("<iframe width="560" height="315" src="https://www.youtube.com/embed/lSM0VAqSOeg" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>")
#                           ^
# SyntaxError: invalid syntax

# %% [markdown]
# Click [here]for the youtube video (https://youtu.be/lSM0VAqSOeg)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo ("watch?v=lSM0VAqSOeg")
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/watch?v=lSM0VAqSOeg"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
